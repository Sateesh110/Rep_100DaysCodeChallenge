# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#100-Days-Code-Challenge-:-Round-2" data-toc-modified-id="100-Days-Code-Challenge-:-Round-2-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>100 Days Code Challenge : Round 2</a></span><ul class="toc-item"><li><span><a href="#Block-1" data-toc-modified-id="Block-1-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Block 1</a></span><ul class="toc-item"><li><span><a href="#Day-1" data-toc-modified-id="Day-1-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Day 1</a></span></li><li><span><a href="#Day-2" data-toc-modified-id="Day-2-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Day 2</a></span></li><li><span><a href="#Day-3" data-toc-modified-id="Day-3-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Day 3</a></span></li><li><span><a href="#Day-4" data-toc-modified-id="Day-4-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Day 4</a></span></li><li><span><a href="#Day-5" data-toc-modified-id="Day-5-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Day 5</a></span></li><li><span><a href="#Day-6" data-toc-modified-id="Day-6-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Day 6</a></span></li><li><span><a href="#Day-7" data-toc-modified-id="Day-7-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>Day 7</a></span></li><li><span><a href="#Day-8" data-toc-modified-id="Day-8-1.1.8"><span class="toc-item-num">1.1.8&nbsp;&nbsp;</span>Day 8</a></span></li><li><span><a href="#Day-9" data-toc-modified-id="Day-9-1.1.9"><span class="toc-item-num">1.1.9&nbsp;&nbsp;</span>Day 9</a></span></li><li><span><a href="#Day-10" data-toc-modified-id="Day-10-1.1.10"><span class="toc-item-num">1.1.10&nbsp;&nbsp;</span>Day 10</a></span></li></ul></li><li><span><a href="#Block-2" data-toc-modified-id="Block-2-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Block 2</a></span><ul class="toc-item"><li><span><a href="#Day-11" data-toc-modified-id="Day-11-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Day 11</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 100 Days Code Challenge : Round 2

# %% [markdown]
# I have accepted the challenge (round2 of 100Days Code Challenge). Be accountable on twitter and Document daily log and Python programs on GitHub.
#
#
# My Objectives are :
#
# * To complete "ML(Supervised & UnSupervised learnings) using Sckit-Learn"
# * To complete "Advance NLP with spacy"
# * Build portfolios
#   * To submit 5 Kaggle ML Projects
#   * One hands-on project using MongoDB, Python and Spacy
#   * To submit three articles in Medium
#
#
# CheckList:
#
# 1. Feature Engineering:
#    * Imputation
#    * One-hot encoding
#    * Binning
#    * Scaling
#    * Date Transformations
#    * Dropping Duplicates,Feature split and other transformations
#
#
# 2. Advanced NLP with spacy
#    * Chapter 1: Finding words, phrases, names and concepts (**Completed**)
#    * Chapter 2: Large-scale data analysis with spaCy (**Completed**)
#    * Chapter 3: Processing Pipelines (**Completed**)
#    * Chapter 4: Training a neural network model
#
#
# 3. Regression (Supervised)
#    * Simple Linear Regression (**Completed**)
#    * Multi Linear Regression  (**Completed**)
#    * Ridge
#    * Lasso
#    *
#    * Regression  Metrics (for Evaluation)
#        * Mean Absolute Error
#        * Mean Squared Error
#        * R^2 (**Completed**)
#        * TSS (**Completed**)
#        * ESS (**Completed**)
#        * RSS (**Completed**)
#
#
# 4. Classification (Supervised)
#    * SVR
#    * Linear Support Vector Machines
#    * RBF SVM
#    * Random Forests
#    * Decision Tree
#    * Linear Discriminant Analysis
#    * Naive Bayes
#    * Nearest Neighbhor
#    * Neural Networks
#    * ADA Boost
#    * Logistics Regression
#    * Quadratic Discriminant
#    * Classification Metrics (for Evaluation)
#        * Accuracy
#        * Log Loss
#        * Area Under ROC Curve
#        * Confusion Matrix
#        * F score
#     * Types
#        * Binary Classifier (**Completed**)
#        * Multi Classifier
#
# 5. Clustering(Un-Supervised)
#    * k-Means Clustering
#    * Principal Component Analysis
#    * Hierarchical Clustering
#
# 6. Tree-based Methods
#    * Decision Tree
#    * Bagging
#    * Boosting
#    * Random Forests
#
# 7. Dimension Reduction
#    * Principal Component Regression
#    * Partial Least Squares
#
# 8. Resampling Methods
#    * Bootstrapping
#    * Cross Validation
#    * Overfitting and Underfitting
#
# 9. Hyper Parameters
#    * Grid Search
#    * Random Search
#    * Hyper parameter Tunning
#
# 10. Others
#     * Subset Selection(Foward; Backward; Stepwise; Best)
#     * Shrinkage (Ridge Regression)
#     * Nonlinear Models (Step Function; Piecewise Function; Splines; Generalized Additive Model)

# %%
#import image
from IPython.display import Image

# %%
Image('00_MachineLearning.jpg')

# %% [markdown]
# ## Block 1

# %% [markdown]
# ### Day 1

# %% [markdown]
# Date: 5th Jun 2019
#
# Time Spent : 4hr
#
# Today's progress:  Completed Chapter 1 of Spacy, learned about the data structures, how to work with statistical models, and how to use them to predict linguistic features in the text.

# %% [markdown]
# ### Day 2

# %% [markdown]
# Date: 6th Jun 2019
#
# Time Spent : 4hr
#
# Today's progress:  Completed Chapter 2 of Spacy, learned how to make the most of spaCy's data structures, and how to effectively combine statistical and rule-based approaches for text analysis.

# %% [markdown]
# ### Day 3

# %% [markdown]
# Date: 7th Jun 2019
#
# Time Spent : 2hr
#
# Today's progress:  Started Chapter 3 of Spacy

# %% [markdown]
# ### Day 4

# %% [markdown]
# Date: 8th Jun 2019
#
# Time Spent : 4hr
#
# Today's progress:  Completed Chapter 3 of Spacy, learn what goes on under the hood when you process a text, how to write your own components and add them to the pipeline, and how to use custom attributes to add your own meta data to the documents, spans and tokens.

# %% [markdown]
# ### Day 5

# %% [markdown]
# Date: 9th Jun 2019
#
# Time Spent : 4hr
#
# Today's progress: Completed Simple Linear Regression & Multi Linear Regression

# %% [markdown]
# ### Day 6

# %% [markdown]
# Date: 10th Jun 2019
#
# Time Spent : 4hr
#
# Today's progress: Completed Metrics of Linear Regression - TSS, RSS, ESS,R^2,

# %% [markdown]
# ### Day 7

# %% [markdown]
# Date:11 Jun 2019
#
# Time Spent : 4hr
#
# Today's progress:

# %% [markdown]
# ### Day 8

# %% [markdown]
# Date: 12 Jun 2019
#
# Time Spent : 4hr
#
# Today's progress: Classfication

# %% [markdown]
# ### Day 9

# %% [markdown]
# Date: 13 Jun 2019
#
# Time Spent : 4hr
#
# Today's progress: Classfication

# %% [markdown]
# ### Day 10

# %% [markdown]
# Date: 14 Jun 2019
#
# Time Spent : 4hr
#
# Today's progress: Classfication

# %% [markdown]
# ## Block 2

# %% [markdown]
# ### Day 11
